# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data
data = pd.read_csv(r'C:\Users\ramavija\Desktop\train.csv')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
plt.scatter(X, Y)
data=data.fillna(0)
plt.show()
m = 0
c = 0.0001
L = 0.0001  # The learning Rate
epochs = 100
# The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y) 
plt.plot(X,Y_pred, color='red', linewidth=2)
plt.show()
# Out:
# 0.9988328359958045 0.014452297414544027

# %%
x_n = data['x'].values.reshape(-1,1)
y_n = data['y'].values.reshape(-1,1)

# %%
Y_pred1=Y_pred.to_numpy()
Y_pred1= Y_pred1.reshape(-1,1)

# %%
df = pd.DataFrame({'Actual': y_n.flatten(), 'Predicted': Y_pred1.flatten()})
